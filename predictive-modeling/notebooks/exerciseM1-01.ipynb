# %% [markdown]
# Let's load the penguins dataset

# %%
import pandas as pd

penguins_classification = pd.read_csv('/mnt/c/Users/kevin/OneDrive/2-Data-Science/Data Science/Sklearn-MOOC/predictive-modeling/datasets/penguins_classification.csv')

# %% [markdown]
# Let's do a first exploration of the data

# %%
penguins_classification.head()
# Out:
#    Culmen Length (mm)  Culmen Depth (mm) Species
# 0                39.1               18.7  Adelie
# 1                39.5               17.4  Adelie
# 2                40.3               18.0  Adelie
# 3                36.7               19.3  Adelie
# 4                39.3               20.6  Adelie

# %%
numerical_features = ['Culmen Length (mm)', 'Culmen Depth (mm)']
categorical_features = ['Species']

# %%
#Number of different penguins species in the dataset

penguins_classification['Species'].value_counts()
# Out:
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: Species, dtype: int64

# %%
_= penguins_classification.hist(column='Culmen Length (mm)', bins=20)

# %%
_ = penguins_classification.hist(column='Culmen Depth (mm)', bins=20)

# %%
import seaborn as sns

_ = sns.pairplot(penguins_classification, hue='Species', vars=['Culmen Length (mm)', 'Culmen Depth (mm)'])

# %% [markdown]
# It should be very easy to classify the penguins.
